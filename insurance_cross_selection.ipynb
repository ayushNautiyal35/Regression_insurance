# %%
import pandas as pd

# %%
data=pd.read_csv("train.csv")

# %%
data.head(3)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
#
#    Response
# 0         0
# 1         1
# 2         0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.0+ GB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
data.drop('id',axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# For gender

# %%
gender_counts=data['Gender'].value_counts()
plt.bar(gender_counts.index,gender_counts.values)
plt.show()

# %%
data['Gender']=data['Gender'].map({'Male':0,'Female':1})

# %%
print(data['Gender'].unique())
# Out:
# [0 1]

# %%
data['Gender'].corr(data['Response'])
# Out:
# -0.055212303879478265

# %%
sns.lineplot(y=data['Gender'],x=data['Response'])
plt.show()

# %%
sns.violinplot(x=data['Gender'],y=data['Response'])
# Out:
# <Axes: xlabel='Gender', ylabel='Response'>

# %% [markdown]
# For Age

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   21                1         35.0                   0    1-2 Year
# 1       0   43                1         28.0                   0   > 2 Years
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1

# %%
data['Age'].unique()
# Out:
# array([21, 43, 25, 35, 36, 31, 23, 47, 26, 66, 22, 27, 24, 79, 34, 20, 42,
#        40, 50, 67, 63, 46, 37, 30, 53, 32, 28, 58, 48, 59, 52, 39, 44, 33,
#        41, 57, 51, 45, 68, 74, 29, 49, 55, 61, 60, 65, 54, 38, 56, 71, 62,
#        70, 73, 64, 69, 72, 78, 80, 76, 75, 77, 81, 83, 82, 84, 85],
#       dtype=int64)

# %%
age_counts=data['Age'].value_counts()
plt.bar(age_counts.index,age_counts.values)
plt.show()

# %%
data['Age'].corr(data['Response'])
# Out:
# 0.1221337357945559

# %%
sns.lineplot(x=data['Age'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   21                1         35.0                   0    1-2 Year
# 1       0   43                1         28.0                   0   > 2 Years
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1

# %% [markdown]
# For DL

# %%
data['Driving_License'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dl_counts=data['Driving_License'].value_counts()
plt.bar(dl_counts.index,dl_counts.values)
plt.show()

# %%
data['Driving_License'].value_counts()
# Out:
# Driving_License
# 1    11482041
# 0       22757
# Name: count, dtype: int64

# %%
data['Driving_License'].corr(data['Response'])
# Out:
# 0.009196993733556733

# %%
sns.violinplot(x=data['Driving_License'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   21                1         35.0                   0    1-2 Year
# 1       0   43                1         28.0                   0   > 2 Years
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1

# %% [markdown]
# For region code

# %%
data['Region_Code'].unique()
# Out:
# array([35. , 28. , 14. ,  1. , 15. , 47. , 45. ,  8. , 11. ,  3. , 10. ,
#        12. , 37. , 50. , 30. , 46. , 29. , 16. , 26. , 25. , 41. , 48. ,
#         7. ,  4. , 24. , 36. , 33. ,  2. ,  9. , 27. , 18. , 43. , 49. ,
#        17. , 13. , 38. ,  6. , 21. , 23. ,  0. , 19. ,  5. , 39. , 44. ,
#        20. , 40. , 22. , 32. , 42. , 31. , 34. , 51. , 52. , 39.2])

# %%
region_counts=data['Region_Code'].value_counts()
plt.bar(region_counts.index,region_counts.values)
plt.show()

# %%
data['Region_Code'].corr(data['Response'])
# Out:
# 0.01281632396933449

# %%
sns.lineplot(x=data['Region_Code'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   21                1         35.0                   0    1-2 Year
# 1       0   43                1         28.0                   0   > 2 Years
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1

# %% [markdown]
# For previously insured

# %%
data['Previously_Insured'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
insure_counts=data['Previously_Insured'].value_counts()
plt.bar(insure_counts.index,insure_counts.values)
plt.show()

# %%
data['Previously_Insured'].corr(data['Response'])
# Out:
# -0.34592983426666

# %%
sns.violinplot(x=data['Previously_Insured'],y=data['Response'])
plt.show()

# %%
sns.lineplot(x=data['Previously_Insured'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   21                1         35.0                   0    1-2 Year
# 1       0   43                1         28.0                   0   > 2 Years
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1

# %% [markdown]
# For vehicle age

# %%
data['Vehicle_Age'].unique()
# Out:
# array(['1-2 Year', '> 2 Years', '< 1 Year'], dtype=object)

# %%
vage_counts=data['Vehicle_Age'].value_counts()
plt.bar(vage_counts.index,vage_counts.values)
plt.show()

# %%
data['Vehicle_Age']=data['Vehicle_Age'].map({'1-2 Year':0,'> 2 Years':1,'< 1 Year':2})

# %%
data['Vehicle_Age'].corr(data['Response'])
# Out:
# -0.20046393353995115

# %%
sns.violinplot(x=data['Vehicle_Age'],y=data['Response'])
plt.show()

# %%
sns.lineplot(x=data['Vehicle_Age'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       0   21                1         35.0                   0            0
# 1       0   43                1         28.0                   0            1
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1

# %% [markdown]
# For vehicle damage

# %%
data['Vehicle_Damage'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
damage_counts=data['Vehicle_Damage'].value_counts()
plt.bar(damage_counts.index,damage_counts.values)
plt.show()

# %%
damage_counts
# Out:
# Vehicle_Damage
# Yes    5783229
# No     5721569
# Name: count, dtype: int64

# %%
data['Vehicle_Damage']=data['Vehicle_Damage'].map({'Yes':1,'No':0})

# %%
data['Vehicle_Damage'].corr(data['Response'])
# Out:
# 0.3597798210705488

# %%
sns.violinplot(x=data['Vehicle_Damage'],y=data['Response'])
plt.show()

# %%
sns.lineplot(x=data['Vehicle_Damage'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       0   21                1         35.0                   0            0
# 1       0   43                1         28.0                   0            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1         65101.0                 124.0      187         0
# 1               1         58911.0                  26.0      288         1

# %% [markdown]
# For annual premium

# %%
data['Annual_Premium'].mean()
# Out:
# 30461.370410588694

# %%
data['Annual_Premium'].median()
# Out:
# 31824.0

# %%
data['Annual_Premium'].mode()
# Out:
# 0    2630.0
# Name: Annual_Premium, dtype: float64

# %%
x_max=data['Annual_Premium'].max()

# %%
x_min=data['Annual_Premium'].min()

# %%
data['Annual_Premium'].std()
# Out:
# 16454.74520524573

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
def change_scaling(x):
    res=(x-x_min)/(x_max-x_min)
    return res

data['Annual_Premium']=data['Annual_Premium'].apply(change_scaling)

# %%
data['Annual_Premium'].head()
# Out:
# 0    0.116218
# 1    0.104702
# 2    0.065880
# 3    0.000000
# 4    0.054547
# Name: Annual_Premium, dtype: float64

# %%
data['Annual_Premium'].corr(data['Response'])
# Out:
# 0.03226066947773281

# %%
sns.lineplot(x=data['Annual_Premium'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       0   21                1         35.0                   0            0
# 1       0   43                1         28.0                   0            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1        0.116218                 124.0      187         0
# 1               1        0.104702                  26.0      288         1

# %% [markdown]
# For policy sales channel

# %%
data['Policy_Sales_Channel'].unique()
# Out:
# array([124.,  26., 152., 156., 160.,   8.,  31., 157.,  60., 122.,  15.,
#         30., 147.,   1.,  63., 136., 154.,  18., 135., 151.,   3.,  10.,
#         55., 108.,   7.,  29., 163.,  13., 133., 145.,  25.,  12., 109.,
#         23.,  78.,   4., 153., 150., 146., 120., 107., 155.,  61.,  14.,
#         45.,  11.,  19.,  24.,  52., 132., 125.,  59.,  16.,  22.,  56.,
#         20., 148., 158., 159., 139.,   9., 113., 121.,  21., 111.,  64.,
#        116., 103., 128.,  65.,  37.,  91., 129., 127., 106., 140.,  35.,
#        131.,  17.,  93.,  90.,  36., 118.,  54.,  62., 138.,  42.,  46.,
#         86.,  80.,  68., 119.,  94.,  48.,  47.,  83.,  97.,  70.,  53.,
#         44., 114.,  98.,  88., 110.,  32., 126.,  96.,  99., 130.,  66.,
#        105.,  51.,  38., 137.,  89.,  81.,  92., 117.,  73.,  69.,  49.,
#         87.,  33.,  39.,  50., 123.,  75., 101., 115., 100.,  95.,  57.,
#         71., 134.,  82.,   6.,  58., 104.,  41.,  40.,   2.,  79.,  34.,
# ...

# %%
channel_counts=data['Policy_Sales_Channel'].value_counts()
plt.bar(channel_counts.index,channel_counts.values)
plt.show()

# %%
channel_counts
# Out:
# Policy_Sales_Channel
# 152.0    4166183
# 26.0     2433456
# 124.0    2264490
# 160.0     640380
# 156.0     316693
#           ...
# 102.0          4
# 112.0          3
# 27.0           2
# 6.0            1
# 5.0            1
# Name: count, Length: 152, dtype: int64

# %%
data['Policy_Sales_Channel'].corr(data['Response'])
# Out:
# -0.15273283389447453

# %%
sns.lineplot(x=data['Policy_Sales_Channel'],y=data['Response'])
plt.show()

# %%
data.head(2)
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       0   21                1         35.0                   0            0
# 1       0   43                1         28.0                   0            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1        0.116218                 124.0      187         0
# 1               1        0.104702                  26.0      288         1

# %% [markdown]
# For vintage

# %%
data['Vintage'].unique()
# Out:
# array([187, 288, 254,  76, 294, 197, 190, 262,  36, 125, 215,  30, 203,
#        259, 245, 150, 240, 242, 117, 151, 169, 185, 264,  38, 152, 284,
#         25, 204, 181, 275,  95, 260, 222, 227, 273, 290,  70, 160,  81,
#         20, 168, 267, 286, 130,  92, 171, 113, 158, 208,  42,  94, 189,
#         84, 228, 194, 249, 129,  11, 120,  16, 298, 226, 159, 100, 230,
#        295, 235, 217,  43, 132, 123, 131, 111, 127, 112, 182, 101,  34,
#         80, 135, 292,  22, 163, 110,  29,  19,  77, 241, 232, 192, 280,
#        252, 281, 253, 114,  74, 270,  17, 186,  61, 255,  21, 145,  27,
#         63, 268, 176, 272,  48, 202, 274, 139, 246, 142,  78,  31, 193,
#        137, 248, 108,  56, 238, 165, 256, 237, 247, 205,  15, 218, 282,
#         24,  86,  90,  75,  54, 164, 278,  91,  49, 105, 251, 219,  53,
#        102, 118, 236, 138,  47, 116, 115, 195,  71,  64, 224,  67,  83,
#        201, 180, 279, 244, 206, 200, 257, 172, 283, 166, 261,  26, 155,
# ...

# %%
vintage_counts=data['Vintage'].value_counts()
plt.bar(vintage_counts.index,vintage_counts.values)
plt.show()

# %%
vintage_counts
# Out:
# Vintage
# 187    98018
# 282    96377
# 131    91892
# 256    90945
# 232    85183
#        ...
# 25     16289
# 26     16182
# 32     15460
# 41     15359
# 50     14002
# Name: count, Length: 290, dtype: int64

# %%
data['Vintage'].corr(data['Response'])
# Out:
# -0.015176720374445566

# %%
sns.lineplot(x=data['Vintage'],y=data['Response'])
plt.show()

# %%
correlation_matrix = data.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))  # Set figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
data['Response'].value_counts()
# Out:
# Response
# 0    10089739
# 1     1415059
# Name: count, dtype: int64

# %% [markdown]
# Dividing into test and train

# %%
x=data.drop('Response',axis=1)
y=data['Response']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=32)

# %%
x_train.shape
# Out:
# (7708214, 10)

# %%
x_test.shape
# Out:
# (3796584, 10)

# %% [markdown]
# Model training ML

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,precision_score

# %%
def check(model):
    y_pred=model.predict(x_test)
    print("The confusion matrix: ", confusion_matrix(y_test,y_pred))
    print("The precision score: ", precision_score(y_test,y_pred))
    print("The recall score: ", recall_score(y_test,y_pred))
    print("The accuracy score: ",accuracy_score(y_test,y_pred))

# %%
from sklearn.linear_model import LogisticRegressionCV
#check(LogisticRegressionCV().fit(x_train,y_train))

# %%
from sklearn.naive_bayes import GaussianNB
#check(GaussianNB().fit(x_train,y_train))

# %%
from sklearn.naive_bayes import BernoulliNB
#check(BernoulliNB().fit(x_train,y_train))

# %%
from sklearn.neighbors import KNeighborsClassifier
#check(KNeighborsClassifier().fit(x_train,y_train))

# %%
from sklearn.tree import DecisionTreeClassifier
#check(DecisionTreeClassifier().fit(x_train,y_train))

# %%
from xgboost import XGBClassifier
#check(XGBClassifier().fit(x_train,y_train))

# %%
from catboost import CatBoostClassifier
#check(CatBoostClassifier().fit(x_train,y_train))

# %%
from lightgbm import LGBMClassifier
#check(LGBMClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble import AdaBoostClassifier
#check(AdaBoostClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble import BaggingClassifier
#check(BaggingClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble  import ExtraTreesClassifier
#check(ExtraTreesClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble import GradientBoostingClassifier
#check(GradientBoostingClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
#check(HistGradientBoostingClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble import RandomForestClassifier
#check(RandomForestClassifier().fit(x_train,y_train))

# %%
from sklearn.ensemble import VotingClassifier
xgb_clf = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="logloss")
cat_clf = CatBoostClassifier(random_state=42, verbose=0)
lgbm_clf = LGBMClassifier(random_state=42)


voting_clf = VotingClassifier(
    estimators=[
        ('xgb', xgb_clf),
        ('cat', cat_clf),
        ('lgbm', lgbm_clf)
    ],
    voting='soft'  # 'soft' for probability averaging, 'hard' for majority voting
)


#check(voting_clf.fit(x_train, y_train))

# %% [markdown]
# Accuracy score:
# Logistic: 87% ,
# Naive Bayes: 79% ,
# Knn: 86% ,
# decision tree: 83% ,
# XGB: 87.99% ,
# cat boost: 88% ,
# lgbm: 87.97% ,
# Adaboost: 87.7% ,
# Baagging  classifier: 86.30 ,
# Extra tree classifier: 85.57% ,
# Gradient boosting: 87.7% ,
# HistGradient Boosting: 87.93% ,
# Random Forest Classifier: 86.44% ,
# Voting classifier: 88.05%

# %% [markdown]
# Hyperparameter optimization of XGB,Cat Boost,LGBM

# %% [raw]
# pip install optuna

# %% [raw]
# def optimize_xgb(trial):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 500),
#         'max_depth': trial.suggest_int('max_depth', 3, 10),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
#         'subsample': trial.suggest_float('subsample', 0.6, 1.0),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
#         'gamma': trial.suggest_float('gamma', 0, 5)
#     }
#     model = XGBClassifier(**param, use_label_encoder=False, eval_metric="logloss", random_state=42)
#     model.fit(x_train, y_train)
#     preds = model.predict(x_test)
#     accuracy = accuracy_score(y_test, preds)
#     return accuracy

# %% [raw]
# def optimize_lgbm(trial):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 500),
#         'num_leaves': trial.suggest_int('num_leaves', 20, 150),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
#         'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
#         'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
#         'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
#         'max_depth': trial.suggest_int('max_depth', 3, 15)
#     }
#     model = LGBMClassifier(**param, random_state=42)
#     model.fit(x_train, y_train)
#     preds = model.predict(x_test)
#     accuracy = accuracy_score(y_test, preds)
#     return accuracy

# %% [raw]
# def optimize_catboost(trial):
#     param = {
#         'iterations': trial.suggest_int('iterations', 100, 500),
#         'depth': trial.suggest_int('depth', 4, 10),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
#         'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
#         'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1)
#     }
#     model = CatBoostClassifier(**param, random_state=42, verbose=0)
#     model.fit(x_train, y_train)
#     preds = model.predict(x_test)
#     accuracy = accuracy_score(y_test, preds)
#     return accuracy

# %% [raw]
# import optuna
# # XGBoost optimization
# xgb_study = optuna.create_study(direction='maximize')
# xgb_study.optimize(optimize_xgb, n_trials=50)
# print("Best XGBoost parameters:", xgb_study.best_params)
# print("Best XGBoost accuracy:", xgb_study.best_value)
#
# # LightGBM optimization
# lgbm_study = optuna.create_study(direction='maximize')
# lgbm_study.optimize(optimize_lgbm, n_trials=50)
# print("Best LightGBM parameters:", lgbm_study.best_params)
# print("Best LightGBM accuracy:", lgbm_study.best_value)
#
# # CatBoost optimizationA
# cat_study = optuna.create_study(direction='maximize')
# cat_study.optimize(optimize_catboost, n_trials=50)
# print("Best CatBoost parameters:", cat_study.best_params)
# print("Best CatBoost accuracy:", cat_study.best_value)

# %% [raw]
# # Use best parameters from Optuna
# params = {
#     'xgb_params': xgb_study.best_params,
#     'lgbm_params': lgbm_study.best_params,
#     'cat_params': cat_study.best_params
# }
#
# # Train and evaluate the ensemble
# model, acc = main(x, y, test_size=0.2, random_state=42, **params)

# %%
#final ml_model
ml_model=CatBoostClassifier().fit(x,y)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.2980597	total: 2.38s	remaining: 39m 40s
# 1:	learn: 0.2729996	total: 2.99s	remaining: 24m 51s
# 2:	learn: 0.2681885	total: 3.49s	remaining: 19m 19s
# 3:	learn: 0.2663683	total: 3.92s	remaining: 16m 17s
# 4:	learn: 0.2651770	total: 4.42s	remaining: 14m 40s
# 5:	learn: 0.2641421	total: 4.88s	remaining: 13m 29s
# 6:	learn: 0.2634515	total: 5.35s	remaining: 12m 38s
# 7:	learn: 0.2628506	total: 5.8s	remaining: 11m 58s
# 8:	learn: 0.2623407	total: 6.28s	remaining: 11m 31s
# 9:	learn: 0.2620790	total: 6.75s	remaining: 11m 8s
# 10:	learn: 0.2617263	total: 7.22s	remaining: 10m 49s
# 11:	learn: 0.2614863	total: 7.7s	remaining: 10m 33s
# 12:	learn: 0.2613148	total: 8.13s	remaining: 10m 17s
# 13:	learn: 0.2609453	total: 8.61s	remaining: 10m 6s
# 14:	learn: 0.2606557	total: 9.08s	remaining: 9m 56s
# 15:	learn: 0.2604915	total: 9.51s	remaining: 9m 44s
# 16:	learn: 0.2603102	total: 9.93s	remaining: 9m 34s
# 17:	learn: 0.2601459	total: 10.4s	remaining: 9m 24s
# ...

# %% [markdown]
# For deep learning

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
classifier=Sequential()

# %%
classifier.add(Dense(units=128,kernel_initializer="he_uniform",activation="relu",input_dim=10))
classifier.add(Dense(units=64,kernel_initializer="he_uniform",activation="relu"))
classifier.add(Dense(units=16,kernel_initializer="he_uniform",activation="relu"))
classifier.add(Dense(units=4,kernel_initializer="he_uniform",activation="relu"))
classifier.add(Dense(units=1,kernel_initializer="glorot_uniform",activation="sigmoid"))

# %%
classifier.compile(optimizer="Adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
model_history=classifier.fit(x,y,validation_split=0.34,batch_size=3,epochs=3)
# Out:
# Epoch 1/10
# 2531056/2531056 [==============================] - 4499s 2ms/step - loss: 0.2735 - accuracy: 0.8770 - val_loss: 0.2698 - val_accuracy: 0.8770
# Epoch 2/10
# 2531056/2531056 [==============================] - 3728s 1ms/step - loss: 0.2723 - accuracy: 0.8770 - val_loss: 0.2701 - val_accuracy: 0.8770
# Epoch 3/10
# 2531056/2531056 [==============================] - 3666s 1ms/step - loss: 0.2714 - accuracy: 0.8770 - val_loss: 0.2716 - val_accuracy: 0.8770
# Epoch 4/10
# 2531056/2531056 [==============================] - 3682s 1ms/step - loss: 0.2716 - accuracy: 0.8770 - val_loss: 0.2697 - val_accuracy: 0.8770
# Epoch 5/10
# 2531031/2531056 [============================>.] - ETA: 0s - loss: 0.2744 - accuracy: 0.8770
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[167], line 1
# ...

# %%
classifier.fit(x,y)
# Out:
# 359525/359525 [==============================] - 1331s 4ms/step - loss: 0.2687 - accuracy: 0.8770

# %% [markdown]
# For test data

# %%
test=pd.read_csv("test.csv")

# %%
test.head(2)
# Out:
#          id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  11504798  Female   20                1         47.0                   0
# 1  11504799    Male   47                1         28.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No          2630.0                 160.0      228
# 1    1-2 Year            Yes         37483.0                 124.0      123

# %%
test.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %%
test['Gender']=test['Gender'].map({'Male':0,'Female':1})
test['Vehicle_Age']=test['Vehicle_Age'].map({'1-2 Year':0,'> 2 Years':1,'< 1 Year':2})
test['Vehicle_Damage']=test['Vehicle_Damage'].map({'Yes':1,'No':0})
test['Annual_Premium']=test['Annual_Premium'].apply(change_scaling)

# %%
df=test.drop('id',axis=1)

# %% [raw]
# test['Response']=ml_model.predict(df)

# %%
y_predict=classifier.predict(df)
y_predict=(y_predict>0.5)
test['Response']=y_predict.astype(int)
# Out:
# 239684/239684 [==============================] - 591s 2ms/step

# %%
res={'id':test['id'],'Response':test['Response']}

# %%
res=pd.DataFrame(res)

# %%
res.to_csv("resut.csv",index=False)
